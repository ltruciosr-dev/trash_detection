# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.1.34 🚀 Python-3.9.19 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce RTX 3080, 10000MiB)
# Setup complete ✅ (24 CPUs, 31.2 GB RAM, 24.6/475.3 GB disk)

# %% [markdown]
# ## Download Weights

# %%
# !mkdir -p weights
# !wget -P weights -q https://github.com/THU-MIG/yolov10/releases/download/v1.1/yolov10n.pt
# !wget -P weights -q https://github.com/THU-MIG/yolov10/releases/download/v1.1/yolov10s.pt
# !wget -P weights -q https://github.com/THU-MIG/yolov10/releases/download/v1.1/yolov10m.pt
# !wget -P weights -q https://github.com/THU-MIG/yolov10/releases/download/v1.1/yolov10b.pt
# !wget -P weights -q https://github.com/THU-MIG/yolov10/releases/download/v1.1/yolov10x.pt
# !wget -P weights -q https://github.com/THU-MIG/yolov10/releases/download/v1.1/yolov10l.pt
# !ls -lh weights
# Out:
# total 408M
# -rw-r--r--. 1 ltruciosr ltruciosr  80M May 26 10:53 yolov10b.pt
# -rw-r--r--. 1 ltruciosr ltruciosr 100M May 26 10:53 yolov10l.pt
# -rw-r--r--. 1 ltruciosr ltruciosr  64M May 26 10:54 yolov10m.pt
# -rw-r--r--. 1 ltruciosr ltruciosr  11M May 26 10:54 yolov10n.pt
# -rw-r--r--. 1 ltruciosr ltruciosr  32M May 26 10:54 yolov10s.pt
# -rw-r--r--. 1 ltruciosr ltruciosr 123M May 26 10:54 yolov10x.pt

# %% [markdown]
# ## Train several models

# %% [markdown]
# ### Data v1
#
# `train`
# - model: yolov10x
# - epochs: 5
# - batch: 5
#
# `train2`
# - model: yolov10x
# - epochs: 20
# - batch: 8
# - imgsz: 640
#
# `train3`
# - model: yolov10b
# - epochs: 50
# - batch: 16
# - imgsz: 640

# %%
dataset_yaml = "../data_v1/dataset.yaml"
# %cat {dataset_yaml}
# Out:
# train: /home/ltruciosr/cs_master/semester_1/cs8055/trash_detection/data_v1/train/images
# val: /home/ltruciosr/cs_master/semester_1/cs8055/trash_detection/data_v1/val/images
#
# nc: 21
# names: ['Bottle', 'Bottle cap', 'Cup', 'Lid', 'Other plastic', 'Plastic bag & wrapper', 'Plastic container', 'Plastic glooves', 'Plastic utensils', 'Straw', 'Can', 'Styrofoam piece', 'Paper', 'Paper bag', 'Carton', 'Broken glass', 'Glass jar', 'Aluminium foil', 'Blister pack', 'Scrap metal', 'Cigarette']

# %%
# !yolo task=detect mode=train epochs=5 batch=5 plots=True model=weights/yolov10x.pt data={dataset_yaml}
# Out:
# New https://pypi.org/project/ultralytics/8.2.59 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.34 🚀 Python-3.9.19 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce RTX 3080, 10000MiB)
# ...

# %%
# !yolo task=detect mode=train epochs=20 batch=8 plots=True imgsz=640 model=weights/yolov10x.pt data={dataset_yaml}
# Out:
# New https://pypi.org/project/ultralytics/8.2.59 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.34 🚀 Python-3.9.19 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce RTX 3080, 10000MiB)
# ...

# %%
# !yolo task=detect mode=train epochs=50 batch=12 plots=True imgsz=640 model=weights/yolov10b.pt data={dataset_yaml}
# Out:
# New https://pypi.org/project/ultralytics/8.2.59 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.34 🚀 Python-3.9.19 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce RTX 3080, 10000MiB)
# ...

# %% [markdown]
# `train4`
# - model: yolov10x
# - epochs: 50
# - batch: 8
#
# `train5`
# - model: yolov10b
# - epochs: 100
# - batch: 12
# - imgsz: 640

# %%
# !yolo task=detect mode=train epochs=50 batch=8 plots=True imgsz=640 model=weights/yolov10x.pt data={dataset_yaml}
# Out:
# New https://pypi.org/project/ultralytics/8.2.59 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.34 🚀 Python-3.9.19 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce RTX 3080, 10000MiB)
# ...

# %%
# !yolo task=detect mode=train epochs=100 batch=12 plots=True imgsz=640 model=weights/yolov10b.pt data={dataset_yaml}
# Out:
# New https://pypi.org/project/ultralytics/8.2.59 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.34 🚀 Python-3.9.19 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce RTX 3080, 10000MiB)
# ...

# %% [markdown]
# ### Data v2
#
# `train6`
# - model: yolov10m
# - epochs: 200
# - batch: 32
# - imgsz: 640

# %%
dataset_yaml = "../data_v2/dataset.yaml"
# %cat {dataset_yaml}
# Out:
# train: /home/ltruciosr/cs_master/semester_1/cs8055/trash_detection/data_v2/train/images
# val: /home/ltruciosr/cs_master/semester_1/cs8055/trash_detection/data_v2/val/images
#
# nc: 21
# names: ['Bottle', 'Bottle cap', 'Cup', 'Lid', 'Other plastic', 'Plastic bag & wrapper', 'Plastic container', 'Plastic glooves', 'Plastic utensils', 'Straw', 'Can', 'Styrofoam piece', 'Paper', 'Paper bag', 'Carton', 'Broken glass', 'Glass jar', 'Aluminium foil', 'Blister pack', 'Scrap metal', 'Cigarette']

# %%
# !yolo task=detect mode=train epochs=200 batch=32 plots=True imgsz=640 model=weights/yolov10m.pt data={dataset_yaml}
# Out:
# New https://pypi.org/project/ultralytics/8.2.59 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.34 🚀 Python-3.9.19 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce RTX 3080, 10000MiB)
# ...
